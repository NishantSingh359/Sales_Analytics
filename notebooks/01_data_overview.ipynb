# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### **Data Source**

# %%
BASE_DIR = Path.cwd().resolve().parents[0]
sales = pd.read_csv(f"{BASE_DIR}/data/gold/sales.csv")
customer = pd.read_csv(f"{BASE_DIR}/data/gold/customer.csv")
product = pd.read_csv(f"{BASE_DIR}/data/gold/product.csv")
dim_date = pd.read_csv(f"{BASE_DIR}/data/dim/dim_date.csv")

# %% [markdown]
# ### **Sales Table**
# ---

# %% [markdown]
# #### **Size**

# %%
sales.shape
# Out:
# (60398, 11)

# %%
sales.columns
# Out:
# Index(['sales_key', 'order_number', 'product_key', 'customer_key', 'date_key',
#        'order_date', 'ship_date', 'delivery_date', 'price', 'quantity',
#        'amount'],
#       dtype='object')

# %% [markdown]
# #### **Data Types**

# %%
sales.dtypes
# Out:
# sales_key          int64
# order_number      object
# product_key       object
# customer_key       int64
# date_key           int64
# order_date        object
# ship_date         object
# delivery_date     object
# price            float64
# quantity           int64
# amount           float64
# dtype: object

# %% [markdown]
# #### **Null Values**

# %%
sales.isnull().sum()
# Out:
# sales_key        0
# order_number     0
# product_key      0
# customer_key     0
# date_key         0
# order_date       0
# ship_date        0
# delivery_date    0
# price            7
# quantity         0
# amount           7
# dtype: int64

# %% [markdown]
# #### **Statistics Summary**

# %%
sales[['price', 'quantity', 'amount']].describe()
# Out:
#               price      quantity        amount
# count  60391.000000  60398.000000  60391.000000
# mean     486.092348      1.000414    486.098674
# std      928.494294      0.044011    928.491742
# min        2.000000      1.000000      2.000000
# 25%        8.000000      1.000000      8.000000
# 50%       30.000000      1.000000     30.000000
# 75%      540.000000      1.000000    540.000000
# max     3578.000000     10.000000   3578.000000

# %%
sales['amount'].sum()/sales['']
# Out:
# np.float64(29355985.0)

# %%
sales
# Out:
#        sales_key order_number product_key  customer_key  date_key  order_date  \
# 0              1      SO43697  BK-R93R-62         21768  20101229  2010-12-29
# 1              2      SO43698  BK-M82S-44         28389  20101229  2010-12-29
# 2              3      SO43699  BK-M82S-44         25863  20101229  2010-12-29
# 3              4      SO43700  BK-R50B-62         14501  20101229  2010-12-29
# 4              5      SO43701  BK-M82S-44         11003  20101229  2010-12-29
# ...          ...          ...         ...           ...       ...         ...
# 60393      60394      SO75122     FE-6654         15868  20140128  2014-01-28
# 60394      60395      SO75122     CA-1098         15868  20140128  2014-01-28
# 60395      60396      SO75123     FE-6654         18759  20140128  2014-01-28
# 60396      60397      SO75123     ST-1401         18759  20140128  2014-01-28
# 60397      60398      SO75123     CA-1098         18759  20140128  2014-01-28
#
#         ship_date delivery_date   price  quantity  amount
# 0      2011-01-05    2011-01-10  3578.0         1  3578.0
# 1      2011-01-05    2011-01-10  3400.0         1  3400.0
# 2      2011-01-05    2011-01-10  3400.0         1  3400.0
# 3      2011-01-05    2011-01-10   699.0         1   699.0
# 4      2011-01-05    2011-01-10  3400.0         1  3400.0
# ...           ...           ...     ...       ...     ...
# 60393  2014-02-04    2014-02-09    22.0         1    22.0
# 60394  2014-02-04    2014-02-09     9.0         1     9.0
# 60395  2014-02-04    2014-02-09    22.0         1    22.0
# 60396  2014-02-04    2014-02-09   159.0         1   159.0
# 60397  2014-02-04    2014-02-09     9.0         1     9.0
#
# [60398 rows x 11 columns]

# %% [markdown]
# ### **Product Table**
# ---

# %% [markdown]
# #### **Size**

# %%
product.shape
# Out:
# (295, 9)

# %%
product.columns
# Out:
# Index(['product_key', 'product_name', 'category', 'subcategory',
#        'product_line', 'maintenance', 'cost', 'launch_date',
#        'last_order_date'],
#       dtype='object')

# %% [markdown]
# #### **Data Type**

# %%
product.dtypes
# Out:
# product_key         object
# product_name        object
# category            object
# subcategory         object
# product_line        object
# maintenance         object
# cost               float64
# launch_date         object
# last_order_date     object
# dtype: object

# %% [markdown]
# #### **Null Values**

# %%
product.isnull().sum()
# Out:
# product_key          0
# product_name         0
# category             7
# subcategory          7
# product_line        17
# maintenance          7
# cost                 0
# launch_date          0
# last_order_date    165
# dtype: int64

# %% [markdown]
# #### **Statistics Summary**

# %%
product['cost'].max() - product['cost'].min()
# Out:
# np.float64(2171.0)

# %%
product[['cost']].describe()
# Out:
#               cost
# count   295.000000
# mean    418.830508
# std     520.211742
# min       0.000000
# 25%      31.500000
# 50%     200.000000
# 75%     602.000000
# max    2171.000000

# %% [markdown]
# ### **Customer Table**
# ---

# %% [markdown]
# #### **Size**

# %%
customer.shape
# Out:
# (18484, 7)

# %%
customer.columns
# Out:
# Index(['customer_key', 'first_name', 'last_name', 'gender', 'marital_status',
#        'country', 'birthdate'],
#       dtype='object')

# %% [markdown]
# #### **Data Type**

# %%
customer.dtypes
# Out:
# customer_key       int64
# first_name        object
# last_name         object
# gender            object
# marital_status    object
# country           object
# birthdate         object
# dtype: object

# %% [markdown]
# #### **Null Values**

# %%
customer.isnull().sum()
# Out:
# customer_key         0
# first_name           3
# last_name            2
# gender             109
# marital_status       2
# country            337
# birthdate         7456
# dtype: int64
